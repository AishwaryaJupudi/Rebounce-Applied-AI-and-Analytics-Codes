# %% [markdown]
# <a href="https://colab.research.google.com/github/AishwaryaJupudi/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python_301.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##***Minor Project 3 · Clean, Analyse & Summarise a Real Dataset***

# %% [markdown]
# #Part-1 Load and Understand the data

# %% [markdown]
# ##Importing the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Loading the data

# %%
url = "https://huggingface.co/datasets/aarav912/online-retail/resolve/main/online_retail.csv"
df = pd.read_csv(url)

# %% [markdown]
# ##Displaying the first 10 rows

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...

# %% [markdown]
# ##Checking the shape of the data

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# ##Listing the names of columns

# %%
df.columns.tolist()
# Out:
# ['InvoiceNo',
#  'StockCode',
#  'Description',
#  'Quantity',
#  'InvoiceDate',
#  'UnitPrice',
#  'CustomerID',
#  'Country']

# %% [markdown]
# ##Checking the datatype of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ##Counting the missing values in every column

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# ##Counting the number of duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(5268)

# %% [markdown]
# The CustomerID and Description columns contain many missing values, while InvoiceDate is stored as text and needs to be converted to datetime. These columns require cleaning before further analysis

# %% [markdown]
# #Part - 2 Clean the data

# %%
df_clean = df.copy()        # Create a copy of the original dataset for cleaning and analysis

# %% [markdown]
# ##Missing customer id

# %% [markdown]
# Missing CustomerID values were retained because dropping 135080 transactions could affect the analysis and also CustomerID is not required for the sales and country-level analysis.

# %% [markdown]
# ##Converting invoice date from text to a proper datetime column

# %%
df_clean['InvoiceDate'] = pd.to_datetime(df_clean['InvoiceDate'])

# %%
df_clean["InvoiceDate"].dtype    #dtype('<M8[ns]') is internal representation of datetime
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ##Removing the duplicate rows

# %%
df_clean = df_clean.drop_duplicates()

# %%
df_clean.shape       #checking the shape after dropping  duplicates
# Out:
# (524878, 9)

# %%
df_clean.duplicated().sum()    #checking the duplicate count after cleaning
# Out:
# np.int64(0)

# %% [markdown]
# ##Removing invalid transactions

# %%
df_clean = df_clean[(df_clean['Quantity']>0) & (df['UnitPrice']>0)]

# %%
df_clean.shape
# Out:
# (524878, 9)

# %% [markdown]
# ##Creating a new Sales column using the formula
#     Sales = Quantity × UnitPrice

# %%
df_clean['Sales'] = df_clean['Quantity'] * df_clean['UnitPrice']

# %%
df_clean.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Sales
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34

# %% [markdown]
# #Part - 3 Numpy Analysis

# %% [markdown]
# ##Calculating the mean

# %%
np.mean(df_clean['Sales']),2
# Out:
# (np.float64(20.27539886221179), 2)

# %% [markdown]
# ##Calculating the median

# %%
np.median(df_clean['Sales'])
# Out:
# np.float64(9.92)

# %% [markdown]
# ##Calculating the minimum sales

# %%
np.min(df_clean['Sales'])
# Out:
# 0.001

# %% [markdown]
# ##Calculating the maximum sales

# %%
np.max(df_clean['Sales'])
# Out:
# 168469.6

# %% [markdown]
# #Calculating the standard deviation

# %%
np.std(df_clean['Sales'])
# Out:
# 271.69330748320107

# %% [markdown]
# ##Rounding the values to a workable number of decimel places

# %%
print("Mean:", round(np.mean(df_clean['Sales']),2))
print("Median:",round(np.median(df_clean['Sales']),2))
print("Min:",round(np.min(df_clean['Sales']),3))
print("Max:",round(np.max(df_clean['Sales']),2))
print("Standard Deviation:",round(np.std(df_clean['Sales']),2))
# Out:
# Mean: 20.28
# Median: 9.92
# Min: 0.001
# Max: 168469.6
# Standard Deviation: 271.69

# %% [markdown]
# The mean sales value (20.28) is considerably higher than the median (9.92), indicating that the sales distribution is right-skewed. This suggests that a small number of very large transactions are pulling the mean upward, while most transactions have relatively lower sales values.

# %% [markdown]
# #Part-4 Pandas Filtering

# %% [markdown]
# ##Filtering the the sales above 500

# %%
df_clean[df_clean['Sales']>500]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 178       536387     79321                   CHILLI LIGHTS       192
# 179       536387     22780  LIGHT GARLAND BUTTERFILES PINK       192
# 180       536387     22779      WOODEN OWLS LIGHT GARLAND        192
# 181       536387     22466   FAIRY TALE COTTAGE NIGHTLIGHT       432
# 182       536387     21731   RED TOADSTOOL LED NIGHT LIGHT       432
# ...          ...       ...                             ...       ...
# 540071    581459     22197                  POPCORN HOLDER      1200
# 540421    581483     23843     PAPER CRAFT , LITTLE BIRDIE     80995
# 540425    581485     20749      ASSORTED COLOUR MINI CASES        84
# 540908    581492       DOT                  DOTCOM POSTAGE         1
# 541540    581498       DOT                  DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country      Sales
# ...

# %% [markdown]
# ##Sorting the transactions from high to low based on sales and displaying the 10 largest transactions

# %%
df.sort_values('Sales',ascending=False).head(10)
# Out:
#        InvoiceNo  StockCode                          Description  Quantity  \
# 540421    581483      23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431      23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 222680    556444      22502       PICNIC BASKET WICKER 60 PIECES        60
# 15017     537632  AMAZONFEE                           AMAZON FEE         1
# 299982   A563185          B                      Adjust bad debt         1
# 173382    551697       POST                              POSTAGE         1
# 348325    567423      23243  SET OF TEA COFFEE SUGAR TINS PANTRY      1412
# 160546    550461      21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 52711     540815      21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 421601    573003      23084                   RABBIT NIGHT LIGHT      2400
#
#                InvoiceDate  UnitPrice  CustomerID         Country      Sales
# ...

# %% [markdown]
# #Transactions that come from Germany

# %%
df_clean['Country'].unique()                    #Display unique countries to identify the exact country name for filtering
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Finland',
#        'Austria', 'Bahrain', 'Israel', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
df_clean[df_clean['Country']== 'Germany']
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 1109      536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1110      536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 1111      536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 1112      536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 1113      536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...          ...       ...                                  ...       ...
# 541801    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 541802    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 541803    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 541804    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 541805    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#                InvoiceDate  UnitPrice  CustomerID  Country  Sales
# ...

# %% [markdown]
# ##Transactions that have Quantity above 1000

# %%
df_clean[df_clean['Quantity']>1000]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 4850      536809     84950     ASSORTED COLOUR T-LIGHT HOLDER      1824
# 4945      536830     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 4946      536830     21915             RED  HARMONICA IN BOX       1400
# 6365      536890    17084R              ASSORTED INCENSE PACK      1440
# 16435     537659     22189            CREAM HEART CARD HOLDER      1008
# ...          ...       ...                                ...       ...
# 533812    581115     22413    METAL SIGN TAKE IT OR LEAVE IT       1404
# 534952    581175     23084                 RABBIT NIGHT LIGHT      1440
# 540070    581458     22197                     POPCORN HOLDER      1500
# 540071    581459     22197                     POPCORN HOLDER      1200
# 540421    581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country      Sales
# ...

# %% [markdown]
# ##Do these transactions with quantity above 1000 seem believable?
# There are some believable transactions with quantity above 1000, like Paper craft and Popcorn Holder. But some of the high-quantity orders look unusual, so we cannot say for sure whether they are correct or data entry errors. They have to be carefully verified and considered before making any conclusions.

# %% [markdown]
# #Part - 5  GroupBy and aggregation

# %% [markdown]
# ##Building a summary table with each country in a row

# %%
country_summary = df_clean.groupby('Country').agg(
    Number_of_transactions= ('Country', 'count'),
    Total_sales=('Sales','sum'),
    Average_sales=('Sales','mean')
).reset_index()

# %%
#Rounding the decimal values of Total sales and average sales to 2 decimal places
country_summary['Total_sales']=country_summary['Total_sales'].round(2)
country_summary['Average_sales']=country_summary['Average_sales'].round(2)

# %%
country_summary
# Out:
#                  Country  Number_of_transactions  Total_sales  Average_sales
# 0              Australia                    1181    138453.81         117.23
# 1                Austria                     398     10198.68          25.62
# 2                Bahrain                      18       754.14          41.90
# 3                Belgium                    2031     41196.34          20.28
# 4                 Brazil                      32      1143.60          35.74
# 5                 Canada                     151      3666.38          24.28
# 6        Channel Islands                     747     20440.54          27.36
# 7                 Cyprus                     603     13502.85          22.39
# 8         Czech Republic                      25       826.74          33.07
# 9                Denmark                     380     18955.34          49.88
# 10                  EIRE                    7879    283140.52          35.94
# ...

# %% [markdown]
# ##Five countries that generated the highest total sales

# %%
country_summary.sort_values('Total_sales',ascending=False).head()
# Out:
#            Country  Number_of_transactions  Total_sales  Average_sales
# 36  United Kingdom                  479985   9001744.09          18.75
# 24     Netherlands                    2359    285446.34         121.00
# 10            EIRE                    7879    283140.52          35.94
# 14         Germany                    9025    228678.40          25.34
# 13          France                    8392    209625.37          24.98

# %% [markdown]
# ##Country that has the highest average transaction value

# %%
country_summary.sort_values('Average_sales',ascending=False).head(1)
# Out:
#         Country  Number_of_transactions  Total_sales  Average_sales
# 24  Netherlands                    2359    285446.34          121.0

# %% [markdown]
# ##Transactions of the top-selling country

# %%
Top_country = country_summary.sort_values('Total_sales',ascending=False).head(1)
Top_country
# Out:
#            Country  Number_of_transactions  Total_sales  Average_sales
# 36  United Kingdom                  479985   9001744.09          18.75

# %%
Top_country['Number_of_transactions'].iloc[0]
# Out:
# np.int64(479985)

# %% [markdown]
# 1. The United Kingdom generated the highest total sales, mainly due to its very large number of transactions (479,985), despite having a lower average transaction value of 18.75.
# 2. The Netherlands had the highest average transaction value (121.00), showing that a high total sales value does not necessarily mean a high average transaction value.
#
# Overall, the results demonstrate that a country's total sales are strongly influenced by transaction volume, whereas average sales reflect the typical value of an individual transaction. Therefore, a country can have a lower total sales value but a much higher average transaction value, as observed for the Netherlands.

# %% [markdown]
# #Part - 6 Merge and Region analysis
