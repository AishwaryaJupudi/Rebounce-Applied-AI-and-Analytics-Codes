# %% [markdown]
# <a href="https://colab.research.google.com/github/AishwaryaJupudi/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python_201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Track - A
# #Personal Expense tracker
#
# > This program helps users record and manage their daily expenses. Users can view all expenses and see how much they spend in each category. The program saves the expense data to a file so it can be used again when the program is reopened.
#
# **How to run:** Run all cells, then call main() to start the program.

# %% [markdown]
# ##1. Data Setup

# %% [markdown]
# *Categories*

# %%
categories = [
    "Food",
    "Groceries",
    "Travel",
    "Rent",
    "Electricity",
    "Internet",
    "Repairs",
    "Health",
    "Shopping",
    "Education",
    "Entertainment",
    "Savings",
    "Loan EMI",
    "Other"
]

expenses = []

# %% [markdown]
# *Expenses*

# %%
expenses = {
    "January": [],
    "February": [],
    "March": [],
    "April": [],
    "May": [],
    "June": [],
    "July": [],
    "August": [],
    "September": [],
    "October": [],
    "November": [],
    "December": []
}

# %% [markdown]
# ##2. Add New Expense

# %%
def months():
  for number,month in enumerate(expenses, start = 1):
        print(number,month)
def show_categories():
  for number,category in enumerate(categories,start = 1):
           print(number,category)

# %%
def add_expense():

  # -------------Select month-----------------

  print("Select month:")
  months()

  month_choice = int(input("Enter month number: "))
  month = list(expenses.keys())[month_choice - 1]

  #--------------Select category--------------

  print("Select Category:")
  show_categories()

  category_choice = int(input("Enter category number: "))
  category = categories[category_choice - 1]

  #-----------Enter expense details------------

  amount = float(input("Enter amount: "))

  description = input("Enter description: ")

  date = input("Enter date (dd-mm-yy):")


  #-----------Create expense -----------------

  expense = {
    "category" : category,
    "amount"   : amount,
    "description" : description,
    "date" : date
}

  #----------------Add expense----------------

  expenses[month].append(expense)

  #-------------Confirmation message-----------

  print("Expense added successfully!")

# %%
add_expense()      #Enter the details of the expense
# Out:
# Select month:
# 1 January
# 2 February
# 3 March
# 4 April
# 5 May
# 6 June
# 7 July
# 8 August
# 9 September
# 10 October
# 11 November
# 12 December
# Enter month number: 8
# Select Category:
# 1 Food
# 2 Groceries
# 3 Travel
# 4 Rent
# 5 Electricity
# 6 Internet
# 7 Repairs
# 8 Health
# 9 Shopping
# 10 Education
# 11 Entertainment
# 12 Savings
# 13 Loan EMI
# 14 Other
# Enter category number: 8
# Enter amount: 5000
# Enter description: Regular checkup
# Enter date (dd-mm-yy):11-08-26
# Expense added successfully!

# %% [markdown]
# ##2. View Expenses

# %%
def view_expenses():
  # -------------Select month-----------------

  print("Select month:")
  months()

  month_choice = int(input("Enter month number: "))

  if month_choice < 1 or month_choice > 12 :
    print("Invalid month number")
  else:
     month = list(expenses.keys())[month_choice - 1]
     if len(expenses[month]) == 0:
       print("No expenses found for this month")
     else:
      for expense in expenses[month]:
       print("Date:",expense["date"])
       print("Category:",expense["category"])
       print("Amount: Rs",expense["amount"])
       print("Description:",expense["description"])
       print()

# %%
view_expenses()
# Out:
# Select month:
# 1 January
# 2 February
# 3 March
# 4 April
# 5 May
# 6 June
# 7 July
# 8 August
# 9 September
# 10 October
# 11 November
# 12 December
# Enter month number: 8
# Date: 11-08-26
# Category: Health
# Amount: Rs 5000.0
# Description: Regular checkup

# %% [markdown]
# ##3. Category-wise Totals (yearly and monthly)

# %%
def category_totals():

    print("1. Monthly category totals")
    print("2. Yearly category totals")

    choice = int(input("Enter your choice: "))

    if choice == 1:                           # monthly totals

         # -------------Select month-----------------

        print("Select month:")
        months()

        month_choice = int(input("Enter month number: "))

        if month_choice < 1 or month_choice > 12 :
          print("Invalid month number")
        else:
          month = list(expenses.keys())[month_choice - 1]

          if len(expenses[month]) == 0:
           print("No expenses found for this month")
          else:
           for category in categories:
            total = 0
            for expense in expenses[month]:
              if expense["category"] == category:
               total = total + expense["amount"]
            print("Category:",category)
            print("Total: Rs",total)

    elif choice == 2:                    # Yearly totals

     for category in categories:
        total = 0

        for month in expenses:
            for expense in expenses[month]:
                if expense["category"] == category:
                    total = total + expense["amount"]

        print("Category:",category)
        print("Total:Rs",total)
    else:
          print("Invalid choice")

# %%
category_totals()
# Out:
# 1. Monthly category totals
# 2. Yearly category totals
# Enter your choice: 1
# Select month:
# 1 January
# 2 February
# 3 March
# 4 April
# 5 May
# 6 June
# 7 July
# 8 August
# 9 September
# 10 October
# 11 November
# 12 December
# Enter month number: 7
# Category: Food
# Total: Rs 0
# Category: Groceries
# Total: Rs 0
# Category: Travel
# Total: Rs 0
# Category: Rent
# Total: Rs 0
# Category: Electricity
# Total: Rs 0
# Category: Internet
# Total: Rs 0
# Category: Repairs
# Total: Rs 0
# Category: Health
# Total: Rs 5500.0
# Category: Shopping
# Total: Rs 0
# Category: Education
# Total: Rs 0
# Category: Entertainment
# Total: Rs 0
# Category: Savings
# Total: Rs 0
# Category: Loan EMI
# Total: Rs 0
# Category: Other
# Total: Rs 0

# %% [markdown]
# ##4. View Total Amount spent

# %%
def total_amount_spent():

  total = 0
  for month in expenses:
    for expense in expenses[month]:
      total = total + expense["amount"]
  return total

# %%
print("Total amount spent: Rs", total_amount_spent())
# Out:
# Total amount spent: Rs 10500.0

# %% [markdown]
# ##5. File Handling

# %%
def save_expenses():

  #open the file in write mode
  file = open("expenses.txt", "w")

  #Go through each month
  for month in expenses:
    file.write(month + "\n")                            #month name to the file
    for expense in expenses[month]:                     #expenses in the current month
      file.write("Date:" + expense["date"] + "\n")
      file.write("Category:" + expense["category"]+"\n")  #write expense details
      file.write ("Amount:"+ str(expense["amount"]) + "\n")
      file.write("Description"+ expense["description"])

  file.close()                                       #close file

  print("Expenses saved successfully!")

# %%
save_expenses()
# Out:
# Expenses saved successfully!

# %% [markdown]
# ##6. Load expenses

# %%
def load_expenses():

  #open the file in read mode
  file = open("expenses.txt","r")

  #Read all lines from the file
  lines = file.readlines()

  months_list = list(expenses.keys())

  for line in lines:
    line = line.strip()

    if line in months_list:
      current_month = line
    elif line.startswith ("Date:"):
      date = line.replace("Date:","").strip()
    elif line.startswith("Category:"):
      category = line.replace("Category:","").strip()
    elif line.startswith("Amount:",):
      amount= float(line.replace("Amount:","").strip())
    elif line.startswith ("Description:"):
      description = line.replace("Description:","").strip()

      expense = {
        "date" : date,
        "category" : category,
        "amount" : amount,
        "description" : description
  }

      expenses[current_month].append(expense)

  file.close()
  print("Expenses loades successfully!!")

# %%
load_expenses()
# Out:
# Expenses loades successfully!!

# %% [markdown]
# ##7. Main Menu

# %%
print("===== EXPENSE TRACKER =====")
print("1. Add expense")
print("2. View expenses")
print("3. Total amount spent")
print("4. Category totals")
print("5. Save expenses")
print("6. Quit")


choice = int(input("Enter your choice:"))

if choice == 1:
  add_expense()
elif choice == 2:
  view_expenses()
elif choice == 3:
 total_amount_spent()
elif choice == 4:
 category_totals()
elif choice == 5:
  save_expenses()
elif choice == 6:
  print("Thank you for using Expense Tracker!!")
else:
  print("Invalid choice")
# Out:
# ===== EXPENSE TRACKER =====
# 1. Add expense
# 2. View expenses
# 3. Total amount spent
# 4. Category totals
# 5. Save expenses
# 6. Quit
# Enter your choice:6
# Thank you for using Expense Tracker!!
